# %%
import pandas as pd
df = pd.read_csv ('Data/Paraguay/Paraguay CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Data/Paraguay/Paraguay CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Data/Paraguay/Paraguay Exchange Rate.csv')
df.plot.line()
