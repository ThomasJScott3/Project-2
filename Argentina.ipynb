# %%
import pandas as pd
df = pd.read_csv ('Argentina Balance of Payments.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Argentina CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Argentina Exchange Rate.csv')
df.plot.line()
