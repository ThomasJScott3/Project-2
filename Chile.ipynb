# %%
import pandas as pd
df = pd.read_csv ('Chile Balance of Payments.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Chile CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Chile Exchange Rate.csv')
df.plot.line()
