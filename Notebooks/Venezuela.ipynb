# %%
import pandas as pd
df = pd.read_csv ('Venezuela CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Venezuela Remittance inflows.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Venezuela Remittance inflows.csv')
df.plot.line()
