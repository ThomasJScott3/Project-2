# %%
import pandas as pd
df = pd.read_csv ('Ecuador CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Ecuador Balance of Payments.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Ecuador Balance of Payments.csv')
df.plot.line()
