# %%
import pandas as pd
df = pd.read_csv ('Project-2/Data/Uruguay/Uruguay Balance of Payments.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Project-2/Data/Uruguay/Uruguay CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Project-2/Data/Uruguay/Uruguay Exchange Rate.csv')
df.plot.line()
