# %%
import pandas as pd
df = pd.read_csv ('/workspace/template-python-flask/datatest/Project-2/Data/Brazil/Brazil_Exchange_Rate.csv')
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df1 = pd.read_csv ('/workspace/template-python-flask/datatest/Project-2/Data/Brazil/Brazil_CPI.csv')
df1.plot.line()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df2 = pd.read_csv ('/workspace/template-python-flask/datatest/Project-2/Data/Brazil/Brazil_Balance_of_Payments.csv')
df2.plot.line()
# Out:
# <AxesSubplot:>
