# %%
import pandas as pd
df = pd.read_csv ('Colombia CPI.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Colombia Exchange Rate.csv')
df.plot.line()

# %%
import pandas as pd
df = pd.read_csv ('Colombia Balance of Payments.csv')
df.plot.line()
